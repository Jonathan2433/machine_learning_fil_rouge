# %%
import pandas as pd
import seaborn

# %%
df = pd.read_csv("train.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df_land_slope = df[['Functional', 'SalePrice']]

# %%
import matplotlib.pyplot as plt

# %%
# df_land_slope.groupby(df["LandSlope"]).mean().plot(kind="bar")
df.groupby(df_land_slope["Functional"]).mean()["SalePrice"].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Functional'>

# %%
plt.scatter(df_land_slope["LotArea"], df["SalePrice"] )

# %%
df_lot_under_25000 = df.loc[(df['LotArea'] < 25000)]

# %%
df_lot_under_25000 = df_lot_under_25000[['LotArea', 'SalePrice']]

# %%
plt.scatter(df_lot_under_25000["LotArea"], df_lot_under_25000["SalePrice"] )

# %%
df_lot_under_25000 = df.loc[(df['LotArea'] < 25000) & (df['SalePrice'] < 250000)]

# %%
df_lot_under_25000 = df_lot_under_25000[['LotArea', 'SalePrice']]

# %%
plt.scatter(df_lot_under_25000["LotArea"], df_lot_under_25000["SalePrice"] )

# %%
df_Fireplaces = df[['Fireplaces', 'SalePrice']]
df.groupby(df_Fireplaces["Fireplaces"]).mean()["SalePrice"].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Fireplaces'>

# %%
df_FireplaceQu = df[['FireplaceQu', 'SalePrice']]
df.groupby(df_FireplaceQu["FireplaceQu"]).mean()["SalePrice"].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='FireplaceQu'>

# %%
df_GarageType = df[['GarageType', 'SalePrice']]

group = df_GarageType.groupby('GarageType')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='GarageType'>

# %%
df_GarageYrBlt = df[['GarageYrBlt', 'SalePrice']]

group = df_GarageYrBlt.groupby('GarageYrBlt')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='GarageYrBlt'>

# %%
df_GarageFinish = df[['GarageFinish', 'SalePrice']]

group = df_GarageFinish.groupby('GarageFinish')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='GarageFinish'>

# %%
df_GarageCars = df[['GarageCars', 'SalePrice']]

group = df_GarageCars.groupby('GarageCars')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='GarageCars'>

# %%
df_GarageArea = df[['GarageArea', 'SalePrice']]

group = df_GarageArea.groupby('GarageArea')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='GarageArea'>

# %%
df_GarageQual = df[['GarageQual', 'SalePrice']]

group = df_GarageQual.groupby('GarageQual')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='GarageQual'>

# %%
 df_GarageCond = df[['GarageCond', 'SalePrice']]

group = df_GarageCond.groupby('GarageCond')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='GarageCond'>

# %%
df_Kitchen = df[['KitchenAbvGr', 'SalePrice']]

group = df_Kitchen.groupby('KitchenAbvGr')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='KitchenAbvGr'>

# %%
df_KitchenQual = df[['KitchenQual', 'SalePrice']]

group = df_KitchenQual.groupby('KitchenQual')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='KitchenQual'>

# %%
df_OpenPorchSF = df[['OpenPorchSF', 'SalePrice']]

group = df_OpenPorchSF.groupby('OpenPorchSF')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='OpenPorchSF'>

# %%
df_EnclosedPorch = df[['EnclosedPorch', 'SalePrice']]

group = df_EnclosedPorch.groupby('EnclosedPorch')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='EnclosedPorch'>

# %%
df_3SsnPorch = df[['3SsnPorch', 'SalePrice']]

group = df_3SsnPorch.groupby('3SsnPorch')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='3SsnPorch'>

# %%
df_ScreenPorch = df[['ScreenPorch', 'SalePrice']]

group = df_ScreenPorch.groupby('ScreenPorch')

group["SalePrice"].mean().sort_values(ascending=True).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='ScreenPorch'>

# %%
df['price_by_area'] = df['SalePrice'] / df['LotArea']

# %%
df['price_by_building'] = df['SalePrice'] / (df['GrLivArea'] + df['GarageArea'] + df['TotalBsmtSF'])

# %%
df['qual_area_pound'] = df['OverallQual'] * df['GrLivArea']

# %%
df['total_rooms'] = df['TotRmsAbvGrd'] + df['BsmtFullBath']

# %%
df['pool_excist'] = df['PoolArea'] > 0

# %%
corr = df.corr()
corr
# Out:
#                          Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id                 1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass         0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage       -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea           -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual       -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond        0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt         -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd      -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea        -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1        -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2        -0.005968   -0.065649     0.049900  0.111170    -0.059119
# ...

# %% [raw]
# corr

# %%
df_corr = df.corr()[df.corr()['SalePrice'] > 0.5]

# %%
df_corr.sort_values('SalePrice', ascending=True)
# Out:
#                          Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# YearRemodAdd      -0.021998    0.040581     0.088866  0.013788     0.550684
# YearBuilt         -0.012713    0.027850     0.123349  0.014228     0.572323
# TotRmsAbvGrd       0.027239    0.040380     0.352096  0.190015     0.427452
# FullBath           0.005587    0.131608     0.198769  0.126031     0.550600
# total_rooms        0.027065    0.040154     0.368973  0.232734     0.447961
# 1stFlrSF           0.010496   -0.251758     0.457181  0.299475     0.476224
# TotalBsmtSF       -0.015415   -0.238518     0.392075  0.260833     0.537808
# GarageArea         0.017634   -0.098672     0.344997  0.180403     0.562022
# GarageCars         0.016570   -0.040110     0.285691  0.154871     0.600671
# price_by_building -0.030049   -0.010185     0.101943  0.108118     0.519153
# GrLivArea          0.008273    0.074853     0.402797  0.263116     0.593007
# ...
